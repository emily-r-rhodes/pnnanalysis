# %%
import matplotlib.pyplot as plt

import skimage.io
from skimage.filters import threshold_mean
from skimage.filters import try_all_threshold

imname = '16_cortex.png'
img = skimage.io.imread(imname)

img2D = img[:, :, 0]

#thresh = try_all_(img2D)
binary = img2D > 0

plt.imshow(binary)
plt.show()

# %%
import scipy.ndimage as ndimage
import matplotlib.pyplot as plt
filled = ndimage.binary_fill_holes(binary).astype(int)

fig = plt.figure(figsize=(3,3))

a = fig.add_subplot(1,1,1)
imgplot = plt.imshow(filled)
a.set_title('Cortex')
a.set_axis_off()

plt.imshow(filled)
plt.show()
fig.savefig('Cortex.png')

# %%
import matplotlib.pyplot as plt

import skimage.io
from skimage.filters import threshold_mean

imname = 'confocal_20x_scan_16_blue.png'
img = skimage.io.imread(imname)

fig = plt.figure(figsize=(3,3))

a = fig.add_subplot(1,1,1)
imgplot = plt.imshow(img)
a.set_title('Brain Image')
a.set_axis_off()

fig.savefig('First.png')
